# %%
import re
import ast
import json
import pandas as pd
from pprint import pprint

from urllib.parse import urlparse
from url_parser import parse_url, get_url, get_base_url

import nltk
from nltk.corpus import stopwords

# %%
custom_stopwords = ['www', 'www.', 'com', 'les', 'org', 'tag', 'html', 'id', 'un', 'win', 
                    'en', 'me', 'php', 'asp', 'aspx', 'cc', 'net']

# %%
def get_size():
    df = pd.read_csv('1.csv')
    print(df.shape)
    df = pd.read_csv('1_label.csv')
    print(df.shape)
    df = pd.read_csv('1_nolabel.csv')
    print(df.shape)
    

def get_iab_categories(iab_categories):
    iab_categories_list = []
    iab_categories = ast.literal_eval(iab_categories)
    for iab_category in iab_categories:
        for value in list(iab_category.values())[:-1]:
            iab_categories_list.append([value, iab_category['score']])
    return iab_categories_list

def get_base_url_(url):
    try:
        return get_base_url(url)
    except:
        return url

def get_domain(url):
    try:
        domain = parse_url(url)['domain']
    except:
        domain = ' '.join(urlparse(url).netloc.split('.'))
    try:
        top_domain = parse_url(url)['top_domain'] or ''
    except:
        top_domain = ''
    try:
        sub_domain = parse_url(url)['sub_domain'] or ''
    except:
        sub_domain = ''
    return domain + ' ' + sub_domain + ' ' + top_domain 
    
def get_path(url):
    try:
        path = parse_url(url)['path']
    except:
        path = urlparse(url).path
    return path

def remove_stop_words(text):
    stop = []
    stop.extend(stopwords.words('english'))
    stop.extend(stopwords.words('french'))
    stop.extend(stopwords.words('spanish'))
    stop.extend(custom_stopwords)
    text = re.sub('[^A-Za-z]+', ' ', str(text)).strip()
    text = ' '.join([word for word in text.split() if word not in (stop)])
    
    return text
    
def clean(df, df_name):    
    df_nolabel = df[df['iabCategories'].isnull()]
    df_nolabel.to_csv(f'{df_name}_nolabel.csv')
    
    df = df[~df['iabCategories'].isnull()]
    df = df.fillna('')
    df['iabCategories'] = df['iabCategories'].apply(get_iab_categories)
    df = df.explode('iabCategories', ignore_index = True)
    split = pd.DataFrame(df['iabCategories'].to_list(), columns = ['iab_categories', 'confidence'])
    df = pd.concat([df, split], axis = 1)
    df = df.drop('iabCategories', axis = 1)
    df['base_url'] = df['url'].apply(get_base_url_)
    df['domain'] = df['url'].apply(get_domain) 
    df['path'] = df['url'].apply(get_path)
    df['combine'] = df['channel'] + ' ' + df['domain'] + ' ' + df['path']
    df['combine'] = df['combine'].apply(remove_stop_words)
    df.to_csv(f'{df_name}_label.csv')
    return df

# %%
df = pd.read_csv('../data/clean/1.csv')
df = clean(df, '1')
# get_size()

# %%
df.sample(10)

# %%
df = pd.read_csv('test_label.csv')
df['combine'].to_list()
# Out:
# ['linkedin facs medical professionals news publications news articles acs brief january issue surgeon well coalition expands resources throughout specialty',
#  'facebook rhinews actualites proposition reparation creative lesclavage afro americains recevraient chacun selon democrate',
#  'facebook rhinews actualites proposition reparation creative lesclavage afro americains recevraient chacun selon democrate',
#  'facebook rhinews actualites proposition reparation creative lesclavage afro americains recevraient chacun selon democrate',
#  'facebook rhinews actualites proposition reparation creative lesclavage afro americains recevraient chacun selon democrate',
#  'facebook rhinews actualites proposition reparation creative lesclavage afro americains recevraient chacun selon democrate',
#  'pelispgo',
#  'pelispgo',
#  'pelispgo',
#  'incestflix SloansMoans page',
#  'incestflix SloansMoans page',
#  'incestflix SloansMoans page',
#  'incestflix SloansMoans page',
#  'incestflix SloansMoans page',
#  'incestflix SloansMoans page',
#  'incestflix SloansMoans page',
#  'buzzfun hot quizzes details type image lab cat Fake Face month cpa test',
#  'buzzfun hot quizzes details type image lab cat Fake Face month cpa test',
#  'buzzfun hot quizzes details type image lab cat Fake Face month cpa test',
#  'buzzfun hot quizzes details type image lab cat Fake Face month cpa test',
#  'buzzfun hot quizzes details type image lab cat Fake Face month cpa test',
#  'buzzfun hot quizzes details type image lab cat Fake Face month cpa test',
#  'marleylilly kids product monogrammed youth duck boots',
#  'marleylilly kids product monogrammed youth duck boots',
#  'marleylilly kids product monogrammed youth duck boots',
#  'marleylilly kids product monogrammed youth duck boots',
#  'marleylilly kids product monogrammed youth duck boots',
#  'usps careers welcome htm',
#  'usps careers welcome htm',
#  'google_search tinytap activities gli play big small',
#  'google_search tinytap activities gli play big small',
#  'google_search tinytap activities gli play big small',
#  'google_search tinytap activities gli play big small',
#  'google_search tinytap activities gli play big small',
#  'google_search tinytap activities gli play big small',
#  'google_search tinytap activities gli play big small',
#  'google_search tinytap activities gli play big small',
#  'prmovies best irada Watch online full movie',
#  'prmovies best irada Watch online full movie',
#  'prmovies best irada Watch online full movie',
#  'prmovies best irada Watch online full movie',
#  'prmovies best irada Watch online full movie',
#  'google_search usatoday ftw nfl mock draft draft wire patriots caleb williams',
#  'google_search usatoday ftw nfl mock draft draft wire patriots caleb williams',
#  'google_search usatoday ftw nfl mock draft draft wire patriots caleb williams',
#  'incestflix',
#  'incestflix',
#  'incestflix',
#  'incestflix',
#  'norton get involved Galas gala',
#  'norton get involved Galas gala',
#  'norton get involved Galas gala',
#  'norton get involved Galas gala',
#  'norton get involved Galas gala',
#  'norton get involved Galas gala',
#  'facebook usatoday billswire lists nfl teams super bowl odds divisional round bills ravens ers chiefs',
#  'facebook usatoday billswire lists nfl teams super bowl odds divisional round bills ravens ers chiefs',
#  'facebook usatoday billswire lists nfl teams super bowl odds divisional round bills ravens ers chiefs',
#  'facebook usatoday billswire lists nfl teams super bowl odds divisional round bills ravens ers chiefs',
#  'facebook usatoday billswire lists nfl teams super bowl odds divisional round bills ravens ers chiefs',
#  'facebook usatoday billswire lists nfl teams super bowl odds divisional round bills ravens ers chiefs',
#  'facebook miguezfuneralhome obits karl david daigle',
#  'facebook miguezfuneralhome obits karl david daigle',
#  'facebook miguezfuneralhome obits karl david daigle',
#  'flash-24 live live stream Flash link emb apl player live',
#  'flash-24 live live stream Flash link emb apl player live',
#  'flash-24 live live stream Flash link emb apl player live',
#  'flash-24 live live stream Flash link emb apl player live',
#  'beforeitsnews',
#  'beforeitsnews',
#  'beforeitsnews',
#  'resultsmx hoosierax class',
#  'resultsmx hoosierax class',
#  'resultsmx hoosierax class',
#  'facebook thecelebinsider patricia richardson played mom jill taylor home improvement showed ageless look long gray hair twin daughters wedding',
#  'facebook thecelebinsider patricia richardson played mom jill taylor home improvement showed ageless look long gray hair twin daughters wedding',
#  'facebook thecelebinsider patricia richardson played mom jill taylor home improvement showed ageless look long gray hair twin daughters wedding',
#  'facebook thecelebinsider patricia richardson played mom jill taylor home improvement showed ageless look long gray hair twin daughters wedding',
#  'facebook thecelebinsider patricia richardson played mom jill taylor home improvement showed ageless look long gray hair twin daughters wedding',
#  'face2faceafrica article texas mother dressing burial learned year old daughter killed',
#  'face2faceafrica article texas mother dressing burial learned year old daughter killed',
#  'face2faceafrica article texas mother dressing burial learned year old daughter killed',
#  'face2faceafrica article texas mother dressing burial learned year old daughter killed',
#  'face2faceafrica article texas mother dressing burial learned year old daughter killed',
#  'google_search emardigrasbeads parade schedule',
#  'google_search emardigrasbeads parade schedule',
#  'google_search emardigrasbeads parade schedule',
#  'google_search emardigrasbeads parade schedule',
#  'edgemedianetwork story',
#  'edgemedianetwork story',
#  'edgemedianetwork story',
#  'edgemedianetwork story',
#  'the-pennisaver read huge discount list sen iors fbvlm index TPSsendisc nov gnyob b',
#  'the-pennisaver read huge discount list sen iors fbvlm index TPSsendisc nov gnyob b',
#  'the-pennisaver read huge discount list sen iors fbvlm index TPSsendisc nov gnyob b',
#  'wishtv weather',
#  'wishtv weather',
#  'wishtv weather',
#  'wishtv weather',
#  'wishtv weather',
#  'wishtv weather',
#  'facebook usatoday ugawire alabama safety caleb downs makes surprising commitment ohio state georgia bulldogs football',
#  'facebook usatoday ugawire alabama safety caleb downs makes surprising commitment ohio state georgia bulldogs football',
#  'facebook usatoday ugawire alabama safety caleb downs makes surprising commitment ohio state georgia bulldogs football',
#  'crn news virtualization nutanix svp dishes unexpected consequences broadcom vmware changes',
#  'crn news virtualization nutanix svp dishes unexpected consequences broadcom vmware changes',
#  'crn news virtualization nutanix svp dishes unexpected consequences broadcom vmware changes',
#  'crn news virtualization nutanix svp dishes unexpected consequences broadcom vmware changes',
#  'brookfieldresidential new homes california east bay dublin boulevard ivy',
#  'brookfieldresidential new homes california east bay dublin boulevard ivy',
#  'brookfieldresidential new homes california east bay dublin boulevard ivy',
#  'brookfieldresidential new homes california east bay dublin boulevard ivy',
#  'brookfieldresidential new homes california east bay dublin boulevard ivy',
#  'totalprosports nfl lions injury update tight end sam laporta buccaneers',
#  'totalprosports nfl lions injury update tight end sam laporta buccaneers',
#  'totalprosports nfl lions injury update tight end sam laporta buccaneers',
#  'twitter nodq news said seth rollins status wwe wrestlemania amidst injury news',
#  'twitter nodq news said seth rollins status wwe wrestlemania amidst injury news',
#  'twitter nodq news said seth rollins status wwe wrestlemania amidst injury news',
#  'twitter nodq news said seth rollins status wwe wrestlemania amidst injury news',
#  'twitter nodq news said seth rollins status wwe wrestlemania amidst injury news',
#  'google_search houston-theater',
#  'google_search houston-theater',
#  'google_search houston-theater',
#  'americanmilitarynews traffic madison square garden owner james dolan accused sexual assault linked harvey weinstein complaint',
#  'americanmilitarynews traffic madison square garden owner james dolan accused sexual assault linked harvey weinstein complaint',
#  'americanmilitarynews traffic madison square garden owner james dolan accused sexual assault linked harvey weinstein complaint',
#  'google_search rollerfuneralhomes obituaries',
#  'google_search rollerfuneralhomes obituaries',
#  'google_search rollerfuneralhomes obituaries',
#  'google_search rollerfuneralhomes obituaries',
#  'google_search rollerfuneralhomes obituaries',
#  'google_search rollerfuneralhomes obituaries',
#  'soap2day rs watch tv watch ted full',
#  'soap2day rs watch tv watch ted full',
#  'soap2day rs watch tv watch ted full',
#  'soap2day rs watch tv watch ted full',
#  'soap2day rs watch tv watch ted full',
#  'nodq',
#  'nodq',
#  'nodq',
#  'nodq',
#  'nodq',
#  'nodq',
#  'hoopshype',
#  'hoopshype',
#  'hoopshype',
#  'hoopshype',
#  'hoopshype',
#  'hoopshype',
#  'smbgames super mario stars',
#  'smbgames super mario stars',
#  'smbgames super mario stars',
#  'ewg skindeep browse category Baby soap',
#  'ewg skindeep browse category Baby soap',
#  'ewg skindeep browse category Baby soap',
#  'ewg skindeep browse category Body wash cleanser',
#  'ewg skindeep browse category Body wash cleanser',
#  'ewg skindeep browse category Body wash cleanser',
#  'sru edu news',
#  'sru edu news',
#  'sru edu news',
#  'sru edu news',
#  'sru edu news',
#  'sru edu news',
#  'google_search propertiesincostarica residential lots',
#  'google_search propertiesincostarica residential lots',
#  'google_search propertiesincostarica residential lots',
#  'google_search propertiesincostarica residential lots',
#  'google_search propertiesincostarica residential lots',
#  'google_search 9anime',
#  'google_search 9anime',
#  'google_search 9anime',
#  'google_search 9anime',
#  'google_search 9anime',
#  'pinterest',
#  'hurawatch movie watch aquaman lost kingdom online',
#  'hurawatch movie watch aquaman lost kingdom online',
#  'hurawatch movie watch aquaman lost kingdom online',
#  'diarioaldia nelly swing',
#  'diarioaldia nelly swing',
#  'diarioaldia nelly swing',
#  'diarioaldia nelly swing',
#  'diarioaldia nelly swing',
#  'diarioaldia nelly swing',
#  'instagram charmco',
#  'instagram charmco',
#  'instagram charmco',
#  'instagram charmco',
#  'instagram charmco',
#  'governmentjobs careers tracyca jobs recreation leader ii updated opportunity',
#  'governmentjobs careers tracyca jobs recreation leader ii updated opportunity',
#  'governmentjobs careers tracyca jobs recreation leader ii updated opportunity',
#  'governmentjobs careers tracyca jobs recreation leader ii updated opportunity',
#  'governmentjobs careers lamesa jobs recreation supervisor events',
#  'governmentjobs careers lamesa jobs recreation supervisor events',
#  'governmentjobs careers lamesa jobs recreation supervisor events',
#  'governmentjobs careers lamesa jobs recreation supervisor events',
#  'governmentjobs careers lamesa jobs recreation supervisor events',
#  'governmentjobs careers riversidetransit jobs benefits administrator',
#  'governmentjobs careers riversidetransit jobs benefits administrator',
#  'governmentjobs careers riversidetransit jobs benefits administrator',
#  'governmentjobs careers riversidetransit jobs benefits administrator',
#  'governmentjobs careers riversidetransit jobs benefits administrator',
#  'cygnus-x1 links lcars uss enterprise ncc b',
#  'cygnus-x1 links lcars uss enterprise ncc b',
#  'cygnus-x1 links lcars uss enterprise ncc b',
#  'cygnus-x1 links lcars uss enterprise ncc b',
#  'cygnus-x1 links lcars uss enterprise ncc b',
#  'cygnus-x1 links lcars uss enterprise ncc b',
#  'zoechip movie',
#  'zoechip movie',
#  'zoechip movie',
#  'zoechip movie',
#  'zoechip movie',
#  'boobyday ig girl video boobs round shaped perfect boobs reveal twitter reddit pornhub fansly onlyfans',
#  'boobyday ig girl video boobs round shaped perfect boobs reveal twitter reddit pornhub fansly onlyfans',
#  'boobyday ig girl video boobs round shaped perfect boobs reveal twitter reddit pornhub fansly onlyfans',
#  'boobyday ig girl video boobs round shaped perfect boobs reveal twitter reddit pornhub fansly onlyfans',
#  'boobyday ig girl video boobs round shaped perfect boobs reveal twitter reddit pornhub fansly onlyfans',
#  'marleylilly product monogrammed camera strap',
#  'marleylilly product monogrammed camera strap',
#  'marleylilly product monogrammed camera strap',
#  'marleylilly product monogrammed camera strap',
#  'marleylilly product monogrammed camera strap',
#  'marleylilly product monogrammed camera strap',
#  'google_search localconditions weather louisiana missouri traffic',
#  'google_search localconditions weather louisiana missouri traffic',
#  'google_search localconditions weather louisiana missouri traffic',
#  'flipboard',
#  'flipboard',
#  'flipboard',
#  'flipboard',
#  'flipboard',
#  'flipboard',
#  'google_search purlsoho create make purlwise p',
#  'google_search purlsoho create make purlwise p',
#  'google_search purlsoho create make purlwise p',
#  'google_search purlsoho create make purlwise p',
#  'google_search purlsoho create make purlwise p',
#  'google_search purlsoho create make purlwise p',
#  'gcaptain biden administration faces good options houthis',
#  'fsl-stream im',
#  'fsl-stream im',
#  'fsl-stream im',
#  'plowhearth spark guard p',
#  'plowhearth spark guard p',
#  'facebook buzzfun hot',
#  '9animetv watch another world smartphone',
#  '9animetv watch another world smartphone',
#  '9animetv watch another world smartphone',
#  'facebook televisionseries co newest virgin river update seemingly confirms fans worst concern',
#  'facebook televisionseries co newest virgin river update seemingly confirms fans worst concern',
#  'facebook televisionseries co newest virgin river update seemingly confirms fans worst concern',
#  'facebook televisionseries co newest virgin river update seemingly confirms fans worst concern',
#  'google_search myconsultingoffer consulting consulting vs advisory',
#  'google_search myconsultingoffer consulting consulting vs advisory',
#  'currentobituary member obit',
#  'currentobituary member obit',
#  'unctad publications',
#  'unctad publications',
#  'unctad publications']

# %%
from url_parser import parse_url, get_url, get_base_url
from urllib.parse import urlparse

# %%
urls = [
    'https://www.governmentjobs.com/careers/hawaii/jobs/4347832-0/corrections-education-specialist-iii-correctional-facilities-hawaii-island',
#     'http://161.97.110.226/foursome-2023/#close',
    'https://uk.com/',
#     'https://www.sandipsitaula2023.com.np/2023/12/football-live-10.html',
#     'https://s3.amazonaws.com/facebookaddon/index.html#access_token=EAAPXW9nJcDUBO8IQ8XLC6HDT1beZBsfB1QCSLMvfPi33BbM75h5sawPnPCG4siJJP3sGWOiL9GZCyvbLl2hLE9ZBSCshZAZABC94qknu4RIV1kYqF3caaaHH919Xyzr9Swix3qJDq4U0By20x5NEG6z6JeIuEpAGUKVlHizbOVXml8XKepVYgYPB7W16tBZCBZBWy0ZD&data_access_expiration_time=1713536551&expires_in=5183927',
#     'https://dasao38015.top:3101/',
#     'http://128.199.175.251/contact.html',
#     'http://130.51.20.245/',
#     'https://wm.618851.com:2096/',
#     'https://accessmedicine-mhmedical-com.my.wvsom.edu:2443/',
#     'https://accessmedicine-mhmedical-com.my.wvsom.edu:2443/signin.aspx?msgtype=1&accessRedirect=true&AutoLogin=false&displayIndividualSigninNow=true',
#     'https://accessmedicine-mhmedical-com.my.wvsom.edu:2443/book.aspx?bookID=2988#250593850',
#     'https://xyt.881309.com:2096/',
#     'https://5.253.86.213/room-service-2024/',
#     'http://5.189.136.22/21mph-upload-terbaru/',
]

# %%
# pprint(parse_url('https://purenudism.city/'))
print()
for url in urls:
    pprint(urlparse(url))
    print()
    pprint(parse_url(url))
# Out:
# ParseResult(scheme='https', netloc='www.governmentjobs.com', path='/careers/hawaii/jobs/4347832-0/corrections-education-specialist-iii-correctional-facilities-hawaii-island', params='', query='', fragment='')
#
# {'dir': '/careers/hawaii/jobs/4347832-0/',
#  'domain': 'governmentjobs',
#  'file': 'corrections-education-specialist-iii-correctional-facilities-hawaii-island',
#  'fragment': None,
#  'path': '/careers/hawaii/jobs/4347832-0/corrections-education-specialist-iii-correctional-facilities-hawaii-island',
#  'protocol': 'https',
#  'query': None,
#  'sub_domain': 'www.',
#  'top_domain': 'com',
#  'www': 'www'}
# ParseResult(scheme='https', netloc='uk.com', path='/', params='', query='', fragment='')
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[201], line 6
#       4 pprint(urlparse(url))
#       5 print()
# ----> 6 pprint(parse_url(url))
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/url_parser/__init__.py:144, in parse_url(url)
#     138 def parse_url(url: str) -> dict:
#     139     warnings.warn(
#     140         "parse_url is deprecated, use get_url instead",
#     141         DeprecationWarning
#     142     )
# --> 144     data = get_url(url)
#     145     return data._asdict()
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/url_parser/__init__.py:120, in get_url(url)
#     119 def get_url(url: str) -> UrlObject:
# --> 120     data = _parse_url_with_public_suffix(url)
#     122     object_data = UrlObject(
#     123         protocol=data['protocol'],
#     124         www=data['www'],
#    (...)
#     132         query=data['query'],
#     133     )
#     135     return object_data
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/url_parser/__init__.py:106, in _parse_url_with_public_suffix(url)
#     103         top_domain = tail_gram
#     104         break
# --> 106 data = _parse_url_with_top_domain(url, top_domain)
#     108 return data
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/url_parser/__init__.py:67, in _parse_url_with_top_domain(url, top_domain)
#      52 dict_data = {
#      53     'protocol': None,
#      54     'www': None,
#    (...)
#      62     'query': None,
#      63 }
#      65 match = re.search(regex, url)
# ---> 67 dict_data['protocol'] = match.group('protocol') if match.group('protocol') else None
#      68 dict_data['www'] = match.group('www') if match.group('www') else None
#      69 dict_data['sub_domain'] = match.group('sub_domain') if match.group('sub_domain') else None
#
# AttributeError: 'NoneType' object has no attribute 'group'
