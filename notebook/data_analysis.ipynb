# %%
import pandas as pd
from pprint import pprint

# %%
df = pd.read_csv('../data/train/train.csv')

# %%
print('Shape of data:', df.shape)
df.columns
# Out:
# Shape of data: (9122935, 7)
# Index(['id', 'browserFamily', 'deviceType', 'os', 'iab_categories',
#        'confidence', 'combine'],
#       dtype='object')

# %%
pprint(df['browserFamily'].value_counts())
df['browserFamily'].value_counts().sort_values().plot(kind = 'bar')
# Out:
# 3    6103234
# 0    2858698
# 4     133754
# 2      15479
# 1       7813
# 5       3957
# Name: browserFamily, dtype: int64
# <AxesSubplot: >

# %%
pprint(df['deviceType'].value_counts())
df['deviceType'].value_counts().sort_values().plot(kind = 'bar')
# Out:
# 5    5870459
# 3    2865054
# 6     309844
# 7      51719
# 4      11466
# 1       8159
# 0       6226
# 2          8
# Name: deviceType, dtype: int64
# <AxesSubplot: >

# %%
pprint(df['os'].value_counts())
df['os'].value_counts().sort_values().plot(kind = 'bar')
# Out:
# 3    3846774
# 0    2399492
# 7    1479316
# 5     850465
# 4     367753
# 2     124276
# 6      54135
# 8        688
# 1         36
# Name: os, dtype: int64
# <AxesSubplot: >

# %%
pprint(df['confidence'].value_counts())
df['confidence'].value_counts().sort_values().plot(kind = 'bar')
# Out:
# 1.0    7367157
# 0.5    1755778
# Name: confidence, dtype: int64
# <AxesSubplot: >

# %%
pprint(df['iab_categories'].value_counts())
df['iab_categories'].value_counts().sort_values().plot(kind = 'bar', rot = 90)
# Out:
# 150    1113902
# 95      696863
# 13      562014
# 145     491258
# 30      405665
#         ...
# 90          13
# 148         12
# 127          4
# 130          3
# 6            2
# Name: iab_categories, Length: 167, dtype: int64
# <AxesSubplot: >
